# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinayakirabatti/Practice/blob/master/Lets_begin_with_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#we are going to learn a basic of the Tensorflow
#lets start

# %% [markdown]
# First model :
#
# Consider the following sets of numbers. Can you see the relationship between them?
#
# X : -1 0 1 2 3 4
#
# Y : -2 1 4 7 10 13
#
#
# As you look at them you might notice that the X value is increasing by 1 as you read left to right, and the corresponding Y value is increasing by 3. So you probably think Y=3X plus or minus something. Then you'd probably look at the zero on X and see that Y = 1, and you'd come up with the relationship Y=3X+1.
#
# That's almost exactly how you would use code to train a model to spot the patterns between these items of data!
#
# Now let's look at the code to do it.

# %%
# importing the basics requirements like Tenorflow , keras and numpy
import tensorflow as tf

# %%
import numpy as np

# %%
from tensorflow import keras

# %%
# now we have to create a simple sequential keras model with the help of tf.keras.Sequential() 
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# now we have to compile the model with given loss ans optimizer 
# loss function  = sgd stochastic gradient descent 
# optimizer : mean squares error
model.compile(optimizer="sgd" , loss ="mean_squared_error")

# now next process is provide the data to the model 
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# now we have to train the data to model .. i have trained for 500 times
model.fit(xs,ys ,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 87.3150
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 68.6999
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 54.0544
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 42.5319
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 33.4664
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 26.3341
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 20.7226
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 16.3077
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 12.8341
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.1013
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.9511
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.2593
# ...

# %%
for i in range(1,10):
  print( i ,"--->" ,model.predict([i]))
# Out:
# 1 ---> [[4.0007806]]
# 2 ---> [[7.0004086]]
# 3 ---> [[10.000036]]
# 4 ---> [[12.999664]]
# 5 ---> [[15.999292]]
# 6 ---> [[18.99892]]
# 7 ---> [[21.998549]]
# 8 ---> [[24.998177]]
# 9 ---> [[27.997805]]

# %%
# lests see tomorrow next things! bye
